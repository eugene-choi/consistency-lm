# %%
import torch
import torchtext

# %%
train,val,test = torchtext.datasets.WikiText2(root='.data', split=('train', 'valid', 'test'))

# %%
import torch
import numpy as np
import pandas as pd
import pprint as pp
import matplotlib.pyplot as plt
import seaborn as sns
from omegaconf import OmegaConf
from collections import OrderedDict
import pickle,os,json,operator

import utils as utils
import data as data
from importlib import reload
reload(utils);
reload(data);

from sklearn.feature_extraction.text import CountVectorizer
from yellowbrick.text import FreqDistVisualizer

# %%
dataset_path = '/scratch/ec2684/research/consistency-lm/training_data/wikitext2-sentencized.json'
vocab_path = '/scratch/ec2684/research/consistency-lm/training_data/wikitext2-sentencized.json.vocab.p'
min_context_length=0
num_eos=1

# %%
raw_datasets = json.load(open(dataset_path, 'r'))

# %%
for key in raw_datasets:
    raw_datasets[key] = [x.split() for x in raw_datasets[key]]
vocab_file = '.vocab.p' if num_eos == 1 else f'.vocab_{num_eos}.p'

# %%
if os.path.exists(dataset_path + vocab_file):
    vocab = pickle.load(open(dataset_path+vocab_file, 'rb'))
else:
    vocab = utils.Dictionary(raw_datasets, include_valid=True, num_eos=num_eos)
    pickle.dump(vocab, open(dataset_path+vocab_file, 'wb'))

# %%
tokenized_datasets, eos_stats = utils.tokenize_dataset(raw_datasets, vocab, min_context_length=min_context_length, num_eos=num_eos)
datasets = {name: utils.LMDataset(ds) for name, ds in tokenized_datasets.items()}
# Out:
# train
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 78274/78274 [00:00<00:00, 2557629.16it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 78274/78274 [00:00<00:00, 120576.54it/s]
# cnt_true = 78274
# cnt_false = 0
# True
# 0.0
# valid
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8464/8464 [00:00<00:00, 2559154.34it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8464/8464 [00:00<00:00, 168686.54it/s]
# test
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9708/9708 [00:00<00:00, 2576292.52it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9708/9708 [00:00<00:00, 39066.79it/s]

# %%
stats = {'path': dataset_path,
         'num_train': len(raw_datasets['train']),
         'num_valid': len(raw_datasets['valid']),
         'vocab_size': len(vocab),
         'avg_len': np.mean([len(d) for d in raw_datasets['train']])}

# %%
print("Dataset loaded.\n\tTrain size: %d\tValid size: %d\n\t|V|: %d\tmax len: %d\tavg len: %d\n\tTest size (excluded from vocab): %d" % (
        len(raw_datasets['train']),
        len(raw_datasets['valid']),
        len(vocab),
        max(len(x) for x in raw_datasets['train']),
        stats['avg_len'],
        len(raw_datasets['test']),
))
# Out:
# Dataset loaded.
# 	Train size: 78274	Valid size: 8464
# 	|V|: 33182	max len: 137	avg len: 24
# 	Test size (excluded from vocab): 9708

# %%
tokenized_train_val = []

for key in tokenized_datasets.keys():
    if key == 'test':
        continue
    for seq in tokenized_datasets['train']:
        tokenized_train_val.append(vocab.decode_idx_seq(seq))

# %%
def dummy(doc):
    return doc

vectorizer = CountVectorizer(
        tokenizer=dummy,
        preprocessor=dummy,
    )

# vectorizer = CountVectorizer(lowercase=False)

# %%
docs       = vectorizer.fit_transform(tokenized_train_val)
features   = vectorizer.get_feature_names_out()

# %%
visualizer = FreqDistVisualizer(features=features, orient='v', n=50, size=(1200, 400))
visualizer.fit(docs)
visualizer.show()

visualizer = FreqDistVisualizer(features=features, orient='v', n=50, size=(1200, 400))
visualizer.fit(docs)
visualizer.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# <AxesSubplot:title={'center':'Frequency Distribution of Top 50 tokens'}>

# %%
sorted_tuples = sorted(vocab.counts.items(), key=operator.itemgetter(1), reverse=True)

sorted_dict = OrderedDict()
for k, v in sorted_tuples:
    sorted_dict[k] = v

# %%
for key in list(sorted_dict.keys())[:10]:
    print('{:10}: {:>10}'.format(key,sorted_dict[key]))
# Out:
# the       :     122993
# ,         :     105816
# .         :      73585
# of        :      60887
# and       :      53353
# <unk>     :      44210
# to        :      42369
# in        :      42247
# a         :      36852
# "         :      26480

# %%
counts = list(sorted_dict.values())

x = range(len(counts))
y = {'wikitext-2':counts}
df = pd.DataFrame(data=y, index=x)

# %%
fig = plt.figure(figsize=(10,8))
df.plot(title='log-log plot of wikitext-2 word tokens (sorted by their freq.)',xlabel='tokens',ylabel='freq.',loglog=True)
plt.show()
fig.savefig('wikitext-2_loglog_plot.png',dpi=fig.dpi)

# %%
# logarithmic X
# df.plot.scatter(..., logx=True)
# logarithmic Y
# df.plot.scatter(..., logy=True)
# both
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /state/partition1/job-15306209/ipykernel_190360/2575983163.py in <module>
#       4 # df.plot.scatter(..., logy=True)
#       5 # both
# ----> 6 df.plot.scatter(loglog=True)
#
# TypeError: scatter() missing 2 required positional arguments: 'x' and 'y'

# %%
sorted_cnts = np.array(list(sorted(vocab.counts.values(), reverse=True)))

# %%
epsilon = 1E-5
max_cnt = max(sorted_cnts)

# %%
max_cnt
# Out:
# 122993

# %%
smoothed_cnts = sorted_cnts + epsilon

# %%
1- smoothed_cnts/(2*epsilon+max_cnt)
# Out:
# array([8.13055179e-11, 1.39658355e-01, 4.01713919e-01, ...,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00])

# %%
1-(smoothed_cnts / sum(smoothed_cnts))
# Out:
# array([0.94105596, 0.94928799, 0.9647346 , ..., 1.        , 1.        ,
#        1.        ])

# %%
1/(smoothed_cnts / sum(smoothed_cnts))
# Out:
# array([1.69652446e+01, 1.97191949e+01, 2.83564087e+01, ...,
#        2.08660633e+11, 2.08660633e+11, 2.08660633e+11])

# %%
sorted_cnts / sum(sorted_cnts)
# Out:
# array([0.05894405, 0.05071202, 0.0352654 , ..., 0.        , 0.        ,
#        0.        ])

# %%
df
# Out:
#             0
# 0      122993
# 1      105816
# 2       73585
# 3       60887
# 4       53353
# ...       ...
# 33177       0
# 33178       0
# 33179       0
# 33180       0
# 33181       0
#
# [33182 rows x 1 columns]

# %%
dataset_path='/scratch/ec2684/research/consistency-lm/training_data/wikitext2-sentencized.json'

# %%
lm_path = [
    '/scratch/ec2684/research/consistency-lm/runs/wikitext2_sentencized_tied_seeds/0108_1930/wikitext2_sentencized_tied_seeds____seed=0/wikitextv2',
    '/scratch/ec2684/research/consistency-lm/runs/wikitext2_sentencized_tied_seeds/0108_1930/wikitext2_sentencized_tied_seeds____seed=1/wikitextv2',
    '/scratch/ec2684/research/consistency-lm/runs/wikitext2_sentencized_tied_seeds/0108_1930/wikitext2_sentencized_tied_seeds____seed=2/wikitextv2',
    '/scratch/ec2684/research/consistency-lm/runs/wikitext2_sentencized_tied_seeds/0108_1930/wikitext2_sentencized_tied_seeds____seed=3/wikitextv2',
    '/scratch/ec2684/research/consistency-lm/runs/wikitext2_sentencized_tied_seeds/0108_1930/wikitext2_sentencized_tied_seeds____seed=4/wikitextv2',
    '/scratch/ec2684/research/consistency-lm/runs/wikitext2_sentencized_tied_seeds/0108_1930/wikitext2_sentencized_tied_seeds____seed=5/wikitextv2',
    '/scratch/ec2684/research/consistency-lm/runs/wikitext2_sentencized_tied_seeds/0108_1930/wikitext2_sentencized_tied_seeds____seed=6/wikitextv2',
    '/scratch/ec2684/research/consistency-lm/runs/wikitext2_sentencized_tied_seeds/0108_1930/wikitext2_sentencized_tied_seeds____seed=7/wikitextv2',
]

# %%
strlm_path = [
    '/scratch/ec2684/research/consistency-lm/runs/wikitext2_sentencized_st_lstm/0108_1954/wikitext2_sentencized_st_lstm____st-epsilon=0.01/wikitextv2',
    '/scratch/ec2684/research/consistency-lm/runs/wikitext2_sentencized_st_lstm/0108_1954/wikitext2_sentencized_st_lstm____st-epsilon=0.001/wikitextv2',
    '/scratch/ec2684/research/consistency-lm/runs/wikitext2_sentencized_st_lstm/0108_1954/wikitext2_sentencized_st_lstm____st-epsilon=0.0001/wikitextv2',
]

# %%
osl_path = [
    '/scratch/ec2684/research/consistency-lm/runs/wikitext2_sentencized_st_lstm/test_run/wikitextv2/_235',
]

# %%
focal = [
    '/scratch/ec2684/research/consistency-lm/runs/wikitext2_sentencized_st_lstm/test_run/wikitextv2/focal_gamma4_lr_0.005_lm',
]

# %%
def load_model(model_load_dir):
    if not os.path.exists(model_load_dir):
        raise EOFError("Invalid model load path %s" % model_load_dir)
        
    current_device = "cuda" if torch.cuda.device_count() > 0 else "cpu"
    
    model_dict = torch.load(os.path.join(model_load_dir, "model_best.pt"), map_location=torch.device(current_device))
    return model_dict

# %%
def svd(model_path):
    model = load_model(model_path)
    return torch.linalg.svd(model['model_dict']['projection.weight'], full_matrices=True)

# %%
osl_svd=svd(osl_path[0])

# %%
lm0_svd=svd(lm_path[0])
lm1_svd=svd(lm_path[1])
lm2_svd=svd(lm_path[2])
# lm3_svd=svd(lm_path[3])
# lm4_svd=svd(lm_path[4])

# %%
lm3_svd=svd(lm_path[3])
lm4_svd=svd(lm_path[4])

# %%
lm5_svd=svd(lm_path[5])
lm6_svd=svd(lm_path[6])
lm7_svd=svd(lm_path[7])

# %%
strlm01_svd=svd(strlm_path[0])
strlm001_svd=svd(strlm_path[1])
strlm0001_svd=svd(strlm_path[2])

# %%
strlm_svd=torch.linalg.svd(strlm['model_dict']['projection.weight'], full_matrices=True)

# %%
# import warnings
# warnings.filterwarnings("ignore")
# fig, ax = plt.subplots(figsize=(10,5))
# sns.distplot(lm_svd[1],ax=ax)
# sns.distplot(strlm_svd[1],ax=ax)
# plt.legend(labels=['lm','strlm'])
# ax.set_ylabel('singular values')
# ax.set_xlabel('word embedding dim.')
# ax.set_title('word embedding of LM and STRLM')

# %%
U,S,Vh = osl_svd
cumsum_S=torch.cumsum(S,dim=-1)
print(torch.sum(S))
print(cumsum_S[2]/cumsum_S[-1])
# Out:
# tensor(83354.2656)
# tensor(0.0444)

# %%
def proj(svd):
    U,S,Vh = svd
    proj = U[:,:2]@torch.diag(S[:2])@Vh[:2, :2]
    fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(15,7))
    ax1.scatter(proj[:,0], proj[:,1],alpha=0.5)
    ax2.scatter(proj[:-1,0], proj[:-1,1],alpha=0.5,label='non-eos')
    ax2.scatter(proj[-1,0], proj[-1,1],alpha=1.0,label='<eos>')
    ax2.legend(loc="upper right")
    ax1.axhline(y=0, color='r',linestyle='--')
    ax1.axvline(x=0, color='r',linestyle='--')
    ax2.axhline(y=0, color='r',linestyle='--')
    ax2.axvline(x=0, color='r',linestyle='--')
    plt.show()

# %%
proj(osl_svd)

# %%
proj(lm0_svd)

# %%
proj(lm1_svd)

# %%
proj(lm2_svd)

# %%
proj(lm3_svd)

# %%
proj(lm4_svd)

# %%
proj(lm5_svd)

# %%
proj(lm6_svd)

# %%
proj(lm7_svd)

# %%
proj(strlm01_svd)

# %%
proj(strlm001_svd)

# %%
proj(strlm0001_svd)

# %%
proj(strlm001_svd)

# %%
proj(strlm0001_svd)

# %%
# !ls /scratch/ec2684/research/consistency-lm/runs/wikitext2_sentencized_st_lstm/test_run/wikitextv2/focal_gamma4_lr_0.005_lm/
# Out:
# events.out.tfevents.1644285757.gr003.hpc.nyu.edu  model_best_args.pkl
# final_eval.pkl					  model_best_stats.pkl
# model.pt					  model_best_vocab.pkl
# model_args.pkl					  model_stats.pkl
# model_best.pt					  model_vocab.pkl

# %%
model['model_dict']['projection.bias']
# Out:
# tensor([ -1.0904,   3.9897,   5.8488,  ..., -12.6217, -14.3729,   3.6902])

# %%
lm_file_0 = '/scratch/ec2684/research/consistency-lm/runs/wikitext2_sentencized_tied_seeds/0108_1930/wikitext2_sentencized_tied_seeds____seed=0/wikitextv2/eval/eval.pkl'
st_file_1E_minus_2 = '/scratch/ec2684/research/consistency-lm/runs/wikitext2_sentencized_st_lstm/0108_1954/wikitext2_sentencized_st_lstm____st-epsilon=0.01/wikitextv2/eval/eval.pkl'
st_file_1E_minus_3 = '/scratch/ec2684/research/consistency-lm/runs/wikitext2_sentencized_st_lstm/0108_1954/wikitext2_sentencized_st_lstm____st-epsilon=0.001/wikitextv2/eval/eval.pkl'
st_file_1E_minus_4 = '/scratch/ec2684/research/consistency-lm/runs/wikitext2_sentencized_st_lstm/0108_1954/wikitext2_sentencized_st_lstm____st-epsilon=0.0001/wikitextv2/eval/eval.pkl'

st_finetuned_1E_minus_4 ='/scratch/ec2684/research/consistency-lm/runs/wikitext2_sentencized_st_lstm/0108_1954/wikitext2_sentencized_st_lstm____st-epsilon=0.0001_finetune/wikitextv2/_6/eval/eval.pkl'

st_finetuned_untied_1E_minus_4 ='/scratch/ec2684/research/consistency-lm/runs/wikitext2_sentencized_st_lstm/0108_1954/wikitext2_sentencized_st_lstm____st-epsilon=0.0001_finetune/wikitextv2/_12/eval/eval.pkl'

# st_finetuned_1E_minus_4_w_osl='/scratch/ec2684/research/consistency-lm/runs/wikitext2_sentencized_st_lstm/0108_1954/wikitext2_sentencized_st_lstm____st-epsilon=0.0001_pretrain_finetune/wikitextv2/_109/eval/eval.pkl'

st_finetuned_1E_minus_4_w_osl_65 = '/scratch/ec2684/research/consistency-lm/runs/wikitext2_sentencized_st_lstm/0108_1954/wikitext2_sentencized_st_lstm____st-epsilon=0.0001_pretrain_finetune/65/wikitextv2/eval/eval.pkl'
st_finetuned_1E_minus_4_w_osl_99 = '/scratch/ec2684/research/consistency-lm/runs/wikitext2_sentencized_st_lstm/0108_1954/wikitext2_sentencized_st_lstm____st-epsilon=0.0001_pretrain_finetune/99/wikitextv2/eval/eval.pkl'
st_finetuned_1E_minus_4_w_osl_95 = '/scratch/ec2684/research/consistency-lm/runs/wikitext2_sentencized_st_lstm/0108_1954/wikitext2_sentencized_st_lstm____st-epsilon=0.0001_pretrain_finetune/95/wikitextv2/eval/eval.pkl'

focal = '/scratch/ec2684/research/consistency-lm/runs/wikitext2_sentencized_st_lstm/test_run/wikitextv2/_266/eval/eval.pkl'

# %%
file_dirs = {
    'l.m.': {
        '0': lm_file_0,
    },
    's.t.': {
        '1E-2':st_file_1E_minus_2,
        '1E-3':st_file_1E_minus_3,
        '1E-4':st_file_1E_minus_4,
    },
    'lm_st': {
        '1E-4':st_finetuned_1E_minus_4,
    },
    'lm_st_untied': {
        '1E-4':st_finetuned_untied_1E_minus_4,
    },
    'lm_st_osl': {
        '0.65':st_finetuned_1E_minus_4_w_osl_65,
        '0.95':st_finetuned_1E_minus_4_w_osl_95,
        '0.99':st_finetuned_1E_minus_4_w_osl_99,
    },
    'focal': {
        '4':focal,
    },
}

# %%
def get_data(file_dir: dict):
    data = {}
    for key in sorted(file_dir.keys()):
        if isinstance(file_dir[key], str):
            with open(file_dir[key], 'rb') as f:
                data[key] = pickle.load(f)
        else:
            data[key] = get_data(file_dir[key])
    return data

# %%
data = get_data(file_dirs)

# %%
dataset = 'train'

# %%
def get_prefix(model: str, setting: str):
    return data[model][setting][dataset]['greedy']['decoding_logs'][0]

def get_continuation(model: str, setting: str):
    return data[model][setting][dataset]['greedy']['decoding_logs'][1]

def get_target(setting: str):
    return data['s.t.'][setting][dataset]['greedy']['decoding_logs'][2]

# %%
assert all(get_prefix('s.t.','1E-2') == get_prefix('s.t.',key) for key in data['s.t.'].keys())
assert all(get_prefix('s.t.','1E-2') == get_prefix('l.m.',key) for key in data['l.m.'].keys())

# %%
# def get_continuation(model: str, setting: str, idx: int):
#     return " ".join(get_continuation(model, setting)[idx])
def get_cont_dict(model: str, idx: int):
    continuations = {}
    for key in data[model].keys():
        continuations[key] = get_continuation(model,key)[idx]
    return continuations

# %%
non_terminated = ['a','b','c','c']

# %%
len(set(non_terminated))/ max(len(non_terminated), 1),
# Out:
# (0.75,)

# %%
for key in data.keys():
    print(f'\n\nModel type: {key}')
    for key1 in data[key].keys():
        print(f'- setting: {key1}')
        for key2 in data[key][key1]:
            print(f'{" "*2}- dataset: {key2}')
            for key3 in data[key][key1][key2]:
                if key2 == 'ppl':
                    # print(f'{" "*4}- {key3}')
                    print(f'{" "*4}- {key3}:\t{" "*6}{data[key][key1][key2][key3]}')
                else: 
                    # if key3 != 'greedy':
                        # continue
                    print(f'{" "*4}- decoding algo.: {key3}')
                    for key4 in data[key][key1][key2][key3]:
                        if key4 == 'decoding_logs':
                            continue
                        elif key4 == 'uniq_nonterminated':
                            print(f'{" "*6}- {key4}:\t{data[key][key1][key2][key3][key4]}')
                        else:
                            print(f'{" "*6}- {key4}:\t\t{data[key][key1][key2][key3][key4]}')
                    print()
# Out:
# Model type: focal
# - setting: 4
#   - dataset: train
#     - decoding algo.: beam_2
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		6.875496031746032
#
#     - decoding algo.: beam_4
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		3.7604166666666665
#
#     - decoding algo.: greedy
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		14.260912698412698
#
#     - decoding algo.: sample
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		15.324404761904763
#
#     - decoding algo.: topk-2
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		12.37202380952381
#
#     - decoding algo.: topk-4
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		11.935515873015873
#
#     - decoding algo.: topp-0.2
#       - nonterminated:		0.000496031746031746
#       - uniq_nonterminated:	1.0
#       - avg_len:		13.610615079365079
#
#     - decoding algo.: topp-0.4
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		11.998015873015873
#
#   - dataset: test
#     - decoding algo.: beam_2
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		6.494025545941492
#
#     - decoding algo.: beam_4
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		3.5185414091470952
#
#     - decoding algo.: greedy
#       - nonterminated:		0.00041203131437989287
#       - uniq_nonterminated:	1.0
#       - avg_len:		14.097857437165224
#
#     - decoding algo.: sample
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		14.821178409559126
#
#     - decoding algo.: topk-2
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		12.147816234033787
#
#     - decoding algo.: topk-4
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		11.84919653893696
#
#     - decoding algo.: topp-0.2
#       - nonterminated:		0.00030902348578491963
#       - uniq_nonterminated:	1.0
#       - avg_len:		12.566028018129378
#
#     - decoding algo.: topp-0.4
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		11.727544293366297
#
#   - dataset: random
#     - decoding algo.: beam_2
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		5.415
#
#     - decoding algo.: beam_4
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		1.542
#
#     - decoding algo.: greedy
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		11.224
#
#     - decoding algo.: sample
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		13.181
#
#     - decoding algo.: topk-2
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		10.314
#
#     - decoding algo.: topk-4
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		9.121
#
#     - decoding algo.: topp-0.2
#       - nonterminated:		0.001
#       - uniq_nonterminated:	1.0
#       - avg_len:		15.597
#
#     - decoding algo.: topp-0.4
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		10.542
#
#   - dataset: ppl
#     - train:	      58.445865398254256
#     - test:	      111.15511709883411
#
#
# Model type: l.m.
# - setting: 0
#   - dataset: train
#     - decoding algo.: beam_2
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		8.466765873015873
#
#     - decoding algo.: beam_4
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		4.673115079365079
#
#     - decoding algo.: greedy
#       - nonterminated:		0.011408730158730158
#       - uniq_nonterminated:	1.0
#       - avg_len:		31.356150793650794
#
#     - decoding algo.: sample
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		14.138392857142858
#
#     - decoding algo.: topk-2
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		12.415178571428571
#
#     - decoding algo.: topk-4
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		12.574404761904763
#
#     - decoding algo.: topp-0.2
#       - nonterminated:		0.005952380952380952
#       - uniq_nonterminated:	0.9166666666666666
#       - avg_len:		21.8859126984127
#
#     - decoding algo.: topp-0.4
#       - nonterminated:		0.00248015873015873
#       - uniq_nonterminated:	1.0
#       - avg_len:		15.711309523809524
#
#   - dataset: test
#     - decoding algo.: beam_2
#       - nonterminated:		0.00010300782859497322
#       - uniq_nonterminated:	1.0
#       - avg_len:		7.8563040791100125
#
#     - decoding algo.: beam_4
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		4.142150803461063
#
#     - decoding algo.: greedy
#       - nonterminated:		0.014936135146271116
#       - uniq_nonterminated:	0.7379310344827587
#       - avg_len:		35.57478368355995
#
#     - decoding algo.: sample
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		13.82354758961681
#
#     - decoding algo.: topk-2
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		11.759167696744953
#
#     - decoding algo.: topk-4
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		11.801915945611867
#
#     - decoding algo.: topp-0.2
#       - nonterminated:		0.007931602801812938
#       - uniq_nonterminated:	0.7922077922077922
#       - avg_len:		23.988978162340338
#
#     - decoding algo.: topp-0.4
#       - nonterminated:		0.0044293366295838485
#       - uniq_nonterminated:	0.8604651162790697
#       - avg_len:		17.849299546765554
#
#   - dataset: random
#     - decoding algo.: beam_2
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		18.64
#
#     - decoding algo.: beam_4
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		1.604
#
#     - decoding algo.: greedy
#       - nonterminated:		0.03
#       - uniq_nonterminated:	0.5
#       - avg_len:		53.563
#
#     - decoding algo.: sample
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		12.369
#
#     - decoding algo.: topk-2
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		8.416
#
#     - decoding algo.: topk-4
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		8.832
#
#     - decoding algo.: topp-0.2
#       - nonterminated:		0.04
#       - uniq_nonterminated:	0.5
#       - avg_len:		69.749
#
#     - decoding algo.: topp-0.4
#       - nonterminated:		0.027
#       - uniq_nonterminated:	0.6296296296296297
#       - avg_len:		50.227
#
#   - dataset: ppl
#     - train:	      44.29778304203582
#     - test:	      91.37187499037364
#
#
# Model type: lm_st
# - setting: 1E-4
#   - dataset: train
#     - decoding algo.: greedy
#       - nonterminated:		0.003472222222222222
#       - uniq_nonterminated:	0.7142857142857143
#       - avg_len:		22.271825396825395
#
#   - dataset: test
#     - decoding algo.: greedy
#       - nonterminated:		0.005562422744128554
#       - uniq_nonterminated:	0.3148148148148148
#       - avg_len:		26.55284301606922
#
#   - dataset: random
#     - decoding algo.: greedy
#       - nonterminated:		0.015
#       - uniq_nonterminated:	0.3333333333333333
#       - avg_len:		70.507
#
#   - dataset: ppl
#     - train:	      37.790372683745204
#     - test:	      93.71665461681577
#
#
# Model type: lm_st_osl
# - setting: 0.65
#   - dataset: train
#     - decoding algo.: greedy
#       - nonterminated:		0.001488095238095238
#       - uniq_nonterminated:	1.0
#       - avg_len:		27.71527777777778
#
#   - dataset: test
#     - decoding algo.: greedy
#       - nonterminated:		0.0012360939431396785
#       - uniq_nonterminated:	1.0
#       - avg_len:		27.311701689328387
#
#   - dataset: random
#     - decoding algo.: greedy
#       - nonterminated:		0.03
#       - uniq_nonterminated:	0.2
#       - avg_len:		60.581
#
#   - dataset: ppl
#     - train:	      46.08394041209805
#     - test:	      97.4510496523059
# - setting: 0.95
#   - dataset: train
#     - decoding algo.: greedy
#       - nonterminated:		0.001488095238095238
#       - uniq_nonterminated:	1.0
#       - avg_len:		40.742063492063494
#
#   - dataset: test
#     - decoding algo.: greedy
#       - nonterminated:		0.0025751957148743305
#       - uniq_nonterminated:	0.6
#       - avg_len:		35.454264524103834
#
#   - dataset: random
#     - decoding algo.: greedy
#       - nonterminated:		0.037
#       - uniq_nonterminated:	0.1891891891891892
#       - avg_len:		76.743
#
#   - dataset: ppl
#     - train:	      44.956512508418164
#     - test:	      97.35245885287164
# - setting: 0.99
#   - dataset: train
#     - decoding algo.: greedy
#       - nonterminated:		0.003472222222222222
#       - uniq_nonterminated:	1.0
#       - avg_len:		32.507440476190474
#
#   - dataset: test
#     - decoding algo.: greedy
#       - nonterminated:		0.004120313143798929
#       - uniq_nonterminated:	0.875
#       - avg_len:		29.92583436341162
#
#   - dataset: random
#     - decoding algo.: greedy
#       - nonterminated:		0.045
#       - uniq_nonterminated:	0.2
#       - avg_len:		84.978
#
#   - dataset: ppl
#     - train:	      43.63204503098842
#     - test:	      97.69015930970319
#
#
# Model type: lm_st_untied
# - setting: 1E-4
#   - dataset: train
#     - decoding algo.: greedy
#       - nonterminated:		0.001488095238095238
#       - uniq_nonterminated:	1.0
#       - avg_len:		18.983630952380953
#
#   - dataset: test
#     - decoding algo.: greedy
#       - nonterminated:		0.005253399258343634
#       - uniq_nonterminated:	0.5098039215686274
#       - avg_len:		26.39627111660486
#
#   - dataset: random
#     - decoding algo.: greedy
#       - nonterminated:		0.016
#       - uniq_nonterminated:	0.375
#       - avg_len:		53.451
#
#   - dataset: ppl
#     - train:	      35.33315384328713
#     - test:	      97.13433951778751
#
#
# Model type: s.t.
# - setting: 1E-2
#   - dataset: train
#     - decoding algo.: greedy
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		6.8978174603174605
#
#   - dataset: test
#     - decoding algo.: greedy
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		6.907189946435929
#
#   - dataset: random
#     - decoding algo.: greedy
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		9.69
#
#   - dataset: ppl
#     - train:	      48.17027898776595
#     - test:	      100.53166116975483
# - setting: 1E-3
#   - dataset: train
#     - decoding algo.: greedy
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		25.199900793650794
#
#   - dataset: test
#     - decoding algo.: greedy
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		22.46188710341986
#
#   - dataset: random
#     - decoding algo.: greedy
#       - nonterminated:		0.0
#       - uniq_nonterminated:	0.0
#       - avg_len:		30.343
#
#   - dataset: ppl
#     - train:	      46.15348064010059
#     - test:	      93.65135975967873
# - setting: 1E-4
#   - dataset: train
#     - decoding algo.: greedy
#       - nonterminated:		0.001984126984126984
#       - uniq_nonterminated:	1.0
#       - avg_len:		27.121031746031747
#
#   - dataset: test
#     - decoding algo.: greedy
#       - nonterminated:		0.003296250515039143
#       - uniq_nonterminated:	0.40625
#       - avg_len:		28.78728883395138
#
#   - dataset: random
#     - decoding algo.: greedy
#       - nonterminated:		0.013
#       - uniq_nonterminated:	0.23076923076923078
#       - avg_len:		31.735
#
#   - dataset: ppl
#     - train:	      43.399729087275674
#     - test:	      93.10328636757994

# %%
length_check = lambda data, length: any(len(data[key]) > length for key in data.keys())
length = 30

for idx in range(1000):
    st_cont = get_cont_dict('s.t.',idx)
    lm_cont = get_cont_dict('l.m.',idx)
    lm_st_cont = get_cont_dict('lm_st',idx)
    lm_st_untied_cont = get_cont_dict('lm_st_untied',idx)
    lm_st_osl_cont = get_cont_dict('lm_st_osl',idx)
    focal_cont = get_cont_dict('focal',idx)
    # if length_check(st_cont, length) or length_check(st_cont, length) or length_check(lm_st_cont, length):
    if length_check(st_cont, length) or length_check(st_cont, length) or length_check(lm_st_cont, length):
        print(f'\n\nIndex {idx}:')
        print(f'''(origin): {" ".join(get_target('1E-4')[idx])}''')
        print(f'''(prefix): {" ".join(get_prefix('l.m.','0')[idx][1:])}''')
        print(f'''(target):   {" ".join(get_target('1E-3')[idx][len(get_prefix('l.m.','0')[idx][1:]):])}''')
        print(f'\n(self-terminating):')
        for key in st_cont.keys():
            # print(f'''($\\varepsilon$ = {key}): {" ".join(st_cont[key])}''')
            print(f'''(ε = {key}): {" ".join(st_cont[key])}''')
        print(f'\n(language model):')
        for key in lm_cont.keys():
            print(f'''(seed = {key}): {" ".join(lm_cont[key])}''')
        print(f'\n(pretrain w/ language model & fine-tune w/ self-terminating):')
        for key in lm_st_cont.keys():
            print(f'''(ε = {key}): {" ".join(lm_st_cont[key])}''')
        print(f'\n(pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:')
        for key in lm_st_untied_cont.keys():
            print(f'''(ε = {key}): {" ".join(lm_st_untied_cont[key])}''')
        print(f'\n(pretrain w/ language model & fine-tune w/ self-terminating and osl):')
        for key in lm_st_osl_cont.keys():
            print(f'''(α = {key}): {" ".join(lm_st_osl_cont[key])}''')
        print(f'\n(focal):')
        for key in focal_cont.keys():
            print(f'''(γ = {key}): {" ".join(focal_cont[key])}''')
# Out:
# Index 1:
# (origin): Released in January 2011 in Japan , it is the third game in the Valkyria series .
# (prefix): Released in January 2011 in Japan , it is the
# (target):   third game in the Valkyria series .
#
# (self-terminating):
# (ε = 1E-2): first episode of the series , and the second episode of the series ,
# (ε = 1E-3): first episode of the first season of the American television series The Office of the Year .
# (ε = 1E-4): first song to be released in the United States on November 30 , 2003 .
#
# (language model):
# (seed = 0): first song to be released in the United States .
#
# (pretrain w/ language model & fine-tune w/ self-terminating):
# (ε = 1E-4): first episode of the series , and the second episode of the series , " The <unk> of the Palisades " , was released in the United States on November 18 , 2012 .
#
# (pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:
# (ε = 1E-4): first episode of the series to be released in the United States .
#
# (pretrain w/ language model & fine-tune w/ self-terminating and osl):
# (α = 0.65): first song to be released on the Billboard Hot 100 at number one on the Billboard Hot 100 .
# (α = 0.95): first song to be released in the United States on November 30 , 2003 .
# (α = 0.99): first song to be released on the Fox network .
#
# (focal):
# (γ = 4): first most popular @-@ selling album in the United States .
#
#
# Index 2:
# (origin): unk> the same fusion of tactical and real @-@ time gameplay as its predecessors , the story runs parallel to the first game and follows the " Nameless " , a penal military unit serving the nation of Gallia during the Second Europan War who perform secret black operations and are pitted against the Imperial unit " <unk> Raven " .
# (prefix): unk> the same fusion of tactical and real @-@ time
# (target):   gameplay as its predecessors , the story runs parallel to the first game and follows the " Nameless " , a penal military unit serving the nation of Gallia during the Second Europan War who perform secret black operations and are pitted against the Imperial unit " <unk> Raven " .
#
# (self-terminating):
# (ε = 1E-2): , and the <unk> of the <unk> , the <unk> , and the <unk>
# (ε = 1E-3): <unk> , and the <unk> of the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> of the <unk> .
# (ε = 1E-4): <unk> .
#
# (language model):
# (seed = 0): <unk> , and the <unk> of the <unk>
#
# (pretrain w/ language model & fine-tune w/ self-terminating):
# (ε = 1E-4): <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:
# (ε = 1E-4): <unk> , and the <unk> of the <unk> , the <unk> , and the <unk> , and the <unk> <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating and osl):
# (α = 0.65): <unk> , and the <unk> of the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> .
# (α = 0.95): <unk> , and the <unk> of the <unk> , the <unk> , and the <unk> of the <unk> .
# (α = 0.99): <unk> , and the <unk> of the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> .
#
# (focal):
# (γ = 4): , and the <unk> of the <unk> , the <unk> of the <unk> , is a <unk> of the <unk> .
#
#
# Index 35:
# (origin): Gallian Army Squad 422 , also known as " The Nameless " , are a penal military unit composed of criminals , foreign <unk> , and military offenders whose real names are erased from the records and <unk> officially referred to by numbers .
# (prefix): Gallian Army Squad 422 , also known as " The
# (target):   Nameless " , are a penal military unit composed of criminals , foreign <unk> , and military offenders whose real names are erased from the records and <unk> officially referred to by numbers .
#
# (self-terminating):
# (ε = 1E-2): Gully " , was the first
# (ε = 1E-3): <unk> " , was a " <unk> " , and the <unk> of the <unk> , the <unk> of the <unk> , was the first to be the first to be built in the late 19th century .
# (ε = 1E-4): Gully " , was the first to be built in the city .
#
# (language model):
# (seed = 0): <unk> " , was the first known to be the first of the original series of the series .
#
# (pretrain w/ language model & fine-tune w/ self-terminating):
# (ε = 1E-4): Forge " , was the first to be built in the late 19th century .
#
# (pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:
# (ε = 1E-4): Forge " , is a <unk> , and the <unk> of the <unk> <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating and osl):
# (α = 0.65): Gully " , was the first to be built in the city .
# (α = 0.95): Gully " , was the first to be built in the city .
# (α = 0.99): Gully " , was the first to be built in the city .
#
# (focal):
# (γ = 4): <unk> " , was a <unk> of the <unk> <unk> , and the <unk> of the <unk> .
#
#
# Index 38:
# (origin): unk> young woman who is unknowingly a descendant of the Valkyria .
# (prefix): unk> young woman who is unknowingly a descendant of the
# (target):   Valkyria .
#
# (self-terminating):
# (ε = 1E-2): <unk> .
# (ε = 1E-3): <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> , the <unk> , and the <unk> .
# (ε = 1E-4): <unk> .
#
# (language model):
# (seed = 0): <unk> , a <unk> , and a <unk> , a <unk> , and a <unk> , a <unk> , and a <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating):
# (ε = 1E-4): family .
#
# (pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:
# (ε = 1E-4): family .
#
# (pretrain w/ language model & fine-tune w/ self-terminating and osl):
# (α = 0.65): <unk> , and the <unk> of the <unk> of the <unk> .
# (α = 0.95): <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
# (α = 0.99): <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
#
# (focal):
# (γ = 4): <unk> , and the <unk> of the <unk> .
#
#
# Index 40:
# (origin): As the Nameless officially do not exist , the upper echelons of the Gallian Army exploit the concept of plausible <unk> in order to send them on missions that would otherwise make Gallia lose face in the war .
# (prefix): As the Nameless officially do not exist , the upper
# (target):   echelons of the Gallian Army exploit the concept of plausible <unk> in order to send them on missions that would otherwise make Gallia lose face in the war .
#
# (self-terminating):
# (ε = 1E-2): @-@ level
# (ε = 1E-3): @-@ level <unk> of the <unk> , the <unk> , the <unk> , and the <unk> , the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , the <unk> , and the <unk> , the <unk> , the <unk> , the <unk> , and the <unk> .
# (ε = 1E-4): classes were not <unk> , and the <unk> of the <unk> were not used .
#
# (language model):
# (seed = 0): @-@ level <unk> of the <unk> , the <unk> , and the <unk> , is the <unk> of the <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating):
# (ε = 1E-4): @-@ level cricket was held in the area .
#
# (pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:
# (ε = 1E-4): @-@ level <unk> of the <unk> is the <unk> of the <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating and osl):
# (α = 0.65): @-@ level area was not the same as the <unk> , and the <unk> of the <unk> was not the same .
# (α = 0.95): classes were not <unk> , and the <unk> of the <unk> were <unk> .
# (α = 0.99): classes were not <unk> , and the <unk> of the <unk> were not <unk> .
#
# (focal):
# (γ = 4): @-@ scale <unk> was the first of the first @-@ time , and the <unk> of the <unk> .
#
#
# Index 41:
# (origin): While at times this works to their advantage , such as a successful incursion into Imperial territory , other orders cause certain members of the 422nd great distress .
# (prefix): While at times this works to their advantage , such
# (target):   as a successful incursion into Imperial territory , other orders cause certain members of the 422nd great distress .
#
# (self-terminating):
# (ε = 1E-2): as the <unk> , the <unk> , and the <unk> , the
# (ε = 1E-3): as the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , and the <unk> , the <unk> , the <unk> , and the <unk> , the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> .
# (ε = 1E-4): as the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , is the <unk> of the <unk> .
#
# (language model):
# (seed = 0): as the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating):
# (ε = 1E-4): as the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , was the most common and most powerful and most important of the
#
# (pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:
# (ε = 1E-4): as the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating and osl):
# (α = 0.65): as the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , and the <unk> of the <unk> .
# (α = 0.95): as the <unk> , the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , is a <unk> .
# (α = 0.99): as the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , is the <unk> of the <unk> .
#
# (focal):
# (γ = 4): as the <unk> <unk> , the <unk> of the <unk> , and the <unk> <unk> , the <unk> of the <unk> , and the <unk> <unk> .
#
#
# Index 42:
# (origin): One such member , <unk> , becomes so enraged that he abandons his post and defects into the ranks of Calamity Raven , attached to the ideal of Darcsen independence proposed by their leader , Dahau .
# (prefix): One such member , <unk> , becomes so enraged that
# (target):   he abandons his post and defects into the ranks of Calamity Raven , attached to the ideal of Darcsen independence proposed by their leader , Dahau .
#
# (self-terminating):
# (ε = 1E-2): the <unk> of the <unk> is a <unk> .
# (ε = 1E-3): the <unk> of the <unk> , the <unk> of the <unk> , is a <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , and the <unk> .
# (ε = 1E-4): the <unk> of the <unk> is a <unk> .
#
# (language model):
# (seed = 0): the <unk> of the <unk> is a <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating):
# (ε = 1E-4): the player must be able to make the game .
#
# (pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:
# (ε = 1E-4): the <unk> is a <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating and osl):
# (α = 0.65): the <unk> of the <unk> is a <unk> , and the <unk> of the <unk> of the <unk> .
# (α = 0.95): the <unk> of the <unk> is a <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
# (α = 0.99): the <unk> of the <unk> is a <unk> , and the <unk> of the <unk> of the <unk> .
#
# (focal):
# (γ = 4): the <unk> of the <unk> , the <unk> of the <unk> , is a <unk> of the <unk> of the <unk> .
#
#
# Index 47:
# (origin): <unk> due to these events , and partly due to the major losses in manpower
# (prefix): <unk> due to these events , and partly due to
# (target):   the major losses in manpower
#
# (self-terminating):
# (ε = 1E-2): the lack of <unk> , the <unk> of the
# (ε = 1E-3): the lack of <unk> , the <unk> of the <unk> , the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , the <unk> , the <unk> , and the <unk> of the <unk> .
# (ε = 1E-4): the lack of <unk> .
#
# (language model):
# (seed = 0): the lack of <unk> , the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating):
# (ε = 1E-4): the lack of <unk> , the <unk> of the <unk> , the <unk> , and the <unk> of the <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:
# (ε = 1E-4): the lack of <unk> , the <unk> of the <unk> , the <unk> , and the <unk> of the <unk> , was the first to be built in the <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating and osl):
# (α = 0.65): the lack of <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
# (α = 0.95): the lack of <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
# (α = 0.99): the lack of <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
#
# (focal):
# (γ = 4): the <unk> of the <unk> .
#
#
# Index 48:
# (origin): Gallia suffers towards the end of the war with the Empire , the Nameless are offered a formal position as a squad in the Gallian Army rather than serve as an anonymous shadow force .
# (prefix): Gallia suffers towards the end of the war with the
# (target):   Empire , the Nameless are offered a formal position as a squad in the Gallian Army rather than serve as an anonymous shadow force .
#
# (self-terminating):
# (ε = 1E-2): <unk> of the <unk> , the <unk> of the
# (ε = 1E-3): <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
# (ε = 1E-4): <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> of the <unk> , were the most important and most important of the British forces .
#
# (language model):
# (seed = 0): <unk> , the <unk> of the <unk> , the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating):
# (ε = 1E-4): <unk> , the <unk> and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:
# (ε = 1E-4): <unk> , the <unk> and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating and osl):
# (α = 0.65): <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
# (α = 0.95): <unk> , the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
# (α = 0.99): <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> of the <unk> .
#
# (focal):
# (γ = 4): <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
#
#
# Index 50:
# (origin): Without the support of Maximilian or the chance to prove themselves in the war with Gallia , it is Dahau 's last <
# (prefix): Without the support of Maximilian or the chance to prove
# (target):   themselves in the war with Gallia , it is Dahau 's last <
#
# (self-terminating):
# (ε = 1E-2): the <unk> of the <unk> , the
# (ε = 1E-3): the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> , the <unk> , the <unk> , and the <unk> .
# (ε = 1E-4): the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , is a <unk> of the <unk> , and the <unk> of the <unk> of the <unk> .
#
# (language model):
# (seed = 0): the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating):
# (ε = 1E-4): the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , were the most important of the <unk> of the <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:
# (ε = 1E-4): the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , was the first to be built in the <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating and osl):
# (α = 0.65): the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
# (α = 0.95): the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
# (α = 0.99): the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , is the <unk> of the <unk> .
#
# (focal):
# (γ = 4): the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
#
#
# Index 57:
# (origin): Like its predecessor , Valkyria Chronicles III was developed for PlayStation Portable : this was due to the team wanting to refine the mechanics created for Valkyria Chronicles II , and they had not come up with the " revolutionary " idea that would warrant a new entry for the PlayStation 3 .
# (prefix): Like its predecessor , Valkyria Chronicles III was developed for
# (target):   PlayStation Portable : this was due to the team wanting to refine the mechanics created for Valkyria Chronicles II , and they had not come up with the " revolutionary " idea that would warrant a new entry for the PlayStation 3 .
#
# (self-terminating):
# (ε = 1E-2): the Nintendo DS in the United States .
# (ε = 1E-3): the PlayStation 2 in the United States .
# (ε = 1E-4): the PlayStation 2 , and the PlayStation 2 version was released on March 3 , 2008 .
#
# (language model):
# (seed = 0): the PlayStation 3 , and was released in the United States on November 18 , 2012 .
#
# (pretrain w/ language model & fine-tune w/ self-terminating):
# (ε = 1E-4): the PlayStation 3 , PlayStation 2 , Xbox 360 and Wii , and the PlayStation 2 version of the PlayStation 2 , and the PlayStation 2 version of the Guitar Hero series is released in the United States .
#
# (pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:
# (ε = 1E-4): the PlayStation 3 , PlayStation 2 , Xbox 360 , and Wii .
#
# (pretrain w/ language model & fine-tune w/ self-terminating and osl):
# (α = 0.65): the PlayStation 3 , and the PlayStation 2 version was released on January 3 , 2008 .
# (α = 0.95): the PlayStation 3 , and the PlayStation 2 version was released on December 3 , 2008 .
# (α = 0.99): the PlayStation 3 , and the PlayStation 2 version was released on December 4 , 2008 .
#
# (focal):
# (γ = 4): the first time in the series , and the album was released in the United States on November 18 , 2010 .
#
#
# Index 61:
# (origin): Its story was darker and more somber than that of its predecessor .
# (prefix): Its story was darker and more somber than that of
# (target):   its predecessor .
#
# (self-terminating):
# (ε = 1E-2): the original characters , and the
# (ε = 1E-3): the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
# (ε = 1E-4): the <unk> , and that the " <unk> " was " <unk> " .
#
# (language model):
# (seed = 0): the original series .
#
# (pretrain w/ language model & fine-tune w/ self-terminating):
# (ε = 1E-4): the original series .
#
# (pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:
# (ε = 1E-4): the original series .
#
# (pretrain w/ language model & fine-tune w/ self-terminating and osl):
# (α = 0.65): the <unk> , and the <unk> of the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
# (α = 0.95): the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
# (α = 0.99): the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
#
# (focal):
# (γ = 4): the <unk> .
#
#
# Index 64:
# (origin): A part of this upgrade involved creating unique <unk> models for each character 's body .
# (prefix): A part of this upgrade involved creating unique <unk> models
# (target):   for each character 's body .
#
# (self-terminating):
# (ε = 1E-2): , and the <unk> of the <unk> <unk>
# (ε = 1E-3): , and the <unk> of the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> of the <unk> .
# (ε = 1E-4): , and the <unk> of the <unk> , the <unk> , and the <unk> of the <unk> .
#
# (language model):
# (seed = 0): , and the <unk> of the <unk> <unk>
#
# (pretrain w/ language model & fine-tune w/ self-terminating):
# (ε = 1E-4): , and the <unk> of the <unk> <unk> <unk> <unk> , which was used as a <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:
# (ε = 1E-4): , and the <unk> of the <unk> <unk> <unk> , which was used as a <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating and osl):
# (α = 0.65): , and the <unk> of the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , and the <unk> of the <unk> .
# (α = 0.95): , and the <unk> of the <unk> , the <unk> , and the <unk> of the <unk> .
# (α = 0.99): , and the <unk> of the <unk> <unk> , which was used as a <unk> .
#
# (focal):
# (γ = 4): , and the <unk> of the <unk> , the <unk> of the <unk> , is a <unk> of the <unk> .
#
#
# Index 69:
# (origin): When creating the Nameless Squad , Honjou was faced with the same problem he had had during the first game : the military uniforms essentially destroyed character individuality , despite him needing to create unique characters the player could identify while maintaining a sense of reality within the Valkyria Chronicles world .
# (prefix): When creating the Nameless Squad , Honjou was faced with
# (target):   the same problem he had had during the first game : the military uniforms essentially destroyed character individuality , despite him needing to create unique characters the player could identify while maintaining a sense of reality within the Valkyria Chronicles world .
#
# (self-terminating):
# (ε = 1E-2): the <unk> of the <unk> , the
# (ε = 1E-3): the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
# (ε = 1E-4): the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
#
# (language model):
# (seed = 0): a <unk> , and the <unk> of the <unk> <unk>
#
# (pretrain w/ language model & fine-tune w/ self-terminating):
# (ε = 1E-4): a <unk> , and the <unk> of the <unk> <unk> <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:
# (ε = 1E-4): a <unk> , a <unk> , and a <unk> , a <unk> , and a <unk> , a <unk> , and a <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating and osl):
# (α = 0.65): the <unk> , the <unk> of the <unk> , the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
# (α = 0.95): the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
# (α = 0.99): the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
#
# (focal):
# (γ = 4): the <unk> of the <unk> <unk> , who was the first of the <unk> of the <unk> .
#
#
# Index 73:
# (origin): An early theme he designed around his original vision of the project was rejected .
# (prefix): An early theme he designed around his original vision of
# (target):   the project was rejected .
#
# (self-terminating):
# (ε = 1E-2): the poem , and the
# (ε = 1E-3): the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
# (ε = 1E-4): the <unk> , and the <unk> of the <unk> <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
#
# (language model):
# (seed = 0): the song , " <unk> " , and " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " ...
#
# (pretrain w/ language model & fine-tune w/ self-terminating):
# (ε = 1E-4): the song , which was released in the United States on November 18 , 2003 .
#
# (pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:
# (ε = 1E-4): the song , which was released in the United States on November 18 , 2004 .
#
# (pretrain w/ language model & fine-tune w/ self-terminating and osl):
# (α = 0.65): the <unk> , and the <unk> of the <unk> <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
# (α = 0.95): the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
# (α = 0.99): the <unk> , and the <unk> of the <unk> <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
#
# (focal):
# (γ = 4): the <unk> , and the <unk> of the <unk> of the <unk> .
#
#
# Index 78:
# (origin): The battle themes were designed around the concept of a " modern battle " divorced from a fantasy scenario by using modern musical instruments , constructed to create a sense of <unk> .
# (prefix): The battle themes were designed around the concept of a
# (target):   " modern battle " divorced from a fantasy scenario by using modern musical instruments , constructed to create a sense of <unk> .
#
# (self-terminating):
# (ε = 1E-2): <unk> , and the <unk> of the <unk>
# (ε = 1E-3): <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> , the <unk> , the <unk> , and the <unk> .
# (ε = 1E-4): <unk> , and the <unk> of the <unk> <unk> , which was the first to be the first to be the first to be the first to be the first person in the series .
#
# (language model):
# (seed = 0): <unk> , and the <unk> of the <unk> <unk>
#
# (pretrain w/ language model & fine-tune w/ self-terminating):
# (ε = 1E-4): <unk> , and the <unk> of the <unk> <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:
# (ε = 1E-4): <unk> , and the <unk> of the <unk> <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating and osl):
# (α = 0.65): <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
# (α = 0.95): <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
# (α = 0.99): <unk> , and the <unk> of the <unk> <unk> , which was the first to be a <unk> .
#
# (focal):
# (γ = 4): <unk> , and the <unk> of the <unk> , and the <unk> of the <unk> .
#
#
# Index 82:
# (origin): Its theme was the reason soldiers fought , in particular their wish to protect what was precious to them rather than a sense of responsibility or duty .
# (prefix): Its theme was the reason soldiers fought , in particular
# (target):   their wish to protect what was precious to them rather than a sense of responsibility or duty .
#
# (self-terminating):
# (ε = 1E-2): , and the
# (ε = 1E-3): , and the <unk> of the <unk> , the <unk> of the <unk> , was the first to be used to be the first to be built in the late 20th century .
# (ε = 1E-4): , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
#
# (language model):
# (seed = 0): , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating):
# (ε = 1E-4): , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:
# (ε = 1E-4): , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating and osl):
# (α = 0.65): , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
# (α = 0.95): , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
# (α = 0.99): , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
#
# (focal):
# (γ = 4): , and the <unk> of the <unk> .
#
#
# Index 112:
# (origin): His main criticisms were its length and gameplay repetition , along with expressing regret that it would not be localized .
# (prefix): His main criticisms were its length and gameplay repetition ,
# (target):   along with expressing regret that it would not be localized .
#
# (self-terminating):
# (ε = 1E-2): and the
# (ε = 1E-3): and the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> , the <unk> , and the <unk> .
# (ε = 1E-4): and the film was not a <unk> .
#
# (language model):
# (seed = 0): and the <unk> of the <unk> <unk>
#
# (pretrain w/ language model & fine-tune w/ self-terminating):
# (ε = 1E-4): and the <unk> of the <unk> <unk> was <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:
# (ε = 1E-4): and the <unk> of the <unk> <unk> was a <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating and osl):
# (α = 0.65): and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
# (α = 0.95): and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
# (α = 0.99): and the <unk> of the <unk> <unk> , and the <unk> of the <unk> <unk> .
#
# (focal):
# (γ = 4): and the <unk> of the <unk> .
#
#
# Index 131:
# (origin): They were Senjō no Valkyria 3 : <unk> <unk> <unk>
# (prefix): They were Senjō no Valkyria 3 : <unk> <unk> <unk>
# (target):
#
# (self-terminating):
# (ε = 1E-2): , and the <unk> <unk> .
# (ε = 1E-3): , and the <unk> <unk> <unk> .
# (ε = 1E-4): , and the <unk> <unk> <unk> , which was released in the United States on November
#
# (language model):
# (seed = 0):
#
# (pretrain w/ language model & fine-tune w/ self-terminating):
# (ε = 1E-4): , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <u ...
#
# (pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:
# (ε = 1E-4): , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> ,
#
# (pretrain w/ language model & fine-tune w/ self-terminating and osl):
# (α = 0.65): , and the <unk> <unk> <unk> , and the <unk> <unk> <unk> , and the <unk> <unk> <unk> , and the <unk> <unk> <unk> , and the <unk> <unk> <unk> .
# (α = 0.95): , and the <unk> <unk> <unk> , and the <unk> <unk> <unk> , and the <unk> <unk> <unk> .
# (α = 0.99): , and the <unk> <unk> <unk> , and the <unk> <unk> <unk> , and the <unk> <unk> <unk> .
#
# (focal):
# (γ = 4): , and the <unk> of the <unk> <unk> .
#
#
# Index 143:
# (origin): Besides being the last remaining structure of the original Little Rock Arsenal and one of the oldest buildings in central Arkansas , it was also the birthplace of General Douglas MacArthur , who became the supreme commander of US forces in the South Pacific during World War II .
# (prefix): Besides being the last remaining structure of the original Little
# (target):   Rock Arsenal and one of the oldest buildings in central Arkansas , it was also the birthplace of General Douglas MacArthur , who became the supreme commander of US forces in the South Pacific during World War II .
#
# (self-terminating):
# (ε = 1E-2): Rock , the city was
# (ε = 1E-3): Rock , the <unk> <unk> , which was the first to be built in the late 19th century , was the first to be built in the late 19th century .
# (ε = 1E-4): Rock Arsenal , the <unk> was the first to be built in the city .
#
# (language model):
# (seed = 0): Rock , the <unk> was the first of the <unk> <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating):
# (ε = 1E-4): Rock , the <unk> was the first of the <unk> <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:
# (ε = 1E-4): Rock , the <unk> was the first to be built in the late 19th century .
#
# (pretrain w/ language model & fine-tune w/ self-terminating and osl):
# (α = 0.65): Rock , the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> , the <unk> , and the <unk> of the <unk> , is the <unk> of the <unk> .
# (α = 0.95): Rock Arsenal , the <unk> was the first to be built in the city .
# (α = 0.99): Rock Arsenal , the <unk> was the first to be built in the city .
#
# (focal):
# (γ = 4): <unk> , the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> <unk> , the <unk> of the <unk> , and the <unk> <unk> .
#
#
# Index 161:
# (origin): On January 28 , then Governor Henry Massey Rector informed Captain Totten that he and his soldiers would be " permitted to remain in the possession of the Federal officers until the State , by authority of the people , shall have determined to <unk> their connection with the General Government , " Totten responded to this by telling the Governor that his orders came from the United States Government and began a desperate but ultimately futile dispatch of letters and <unk> asking for reinforcements , although rumors were widely spread that they were already coming .
# (prefix): On January 28 , then Governor Henry Massey Rector informed
# (target):   Captain Totten that he and his soldiers would be " permitted to remain in the possession of the Federal officers until the State , by authority of the people , shall have determined to <unk> their connection with the General Government , " Totten responded to this by telling the Governor that his orders came from the United States Government and began a desperate but ultimately futile dispatch of letters and <unk> asking for reinforcements , although rumors were widely spread that they were already coming .
#
# (self-terminating):
# (ε = 1E-2): that the British government had been
# (ε = 1E-3): that the French government had been the first to be built in the city .
# (ε = 1E-4): that the British government would be the first to be the first to be the first to be the first governor of the United States .
#
# (language model):
# (seed = 0): that the city was " a <unk> of the <unk> " , and the <unk> of the <unk> <unk>
#
# (pretrain w/ language model & fine-tune w/ self-terminating):
# (ε = 1E-4): that the federal government had been <unk> , the <unk> of the <unk> and the <unk> of the <unk> , and the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , were the most important of the <unk> and the <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:
# (ε = 1E-4): that the federal government had been appointed as a candidate for the government .
#
# (pretrain w/ language model & fine-tune w/ self-terminating and osl):
# (α = 0.65): that the British government had been to be the most powerful and political force of the war .
# (α = 0.95): that the British government had been <unk> , and the French government was not the same .
# (α = 0.99): that the British government had been to be the most powerful and political force of the war .
#
# (focal):
# (γ = 4): that the game was " a <unk> of the <unk> " , and that the " <unk> " was " a <unk> of the <unk> " .
#
#
# Index 169:
# (origin): The item was intended simply as a piece of news , but telegraph lines quickly spread the news throughout the state , <unk> procession sentiment .
# (prefix): The item was intended simply as a piece of news
# (target):   , but telegraph lines quickly spread the news throughout the state , <unk> procession sentiment .
#
# (self-terminating):
# (ε = 1E-2): , and the
# (ε = 1E-3): , and the <unk> of the <unk> , the <unk> of the <unk> , was the first to be the first to be used to be the first to be published in the United States .
# (ε = 1E-4): of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
#
# (language model):
# (seed = 0): , and the <unk> of the <unk> <unk>
#
# ...
#
# (pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:
# (ε = 1E-4): " a <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , sweet , <unk> , sweet , <unk> , sweet , sweet , sweet , sweet , spontaneous , spontaneous , spontaneous , spontaneous , spontaneous , shy , shy , ] ] like
#
# (pretrain w/ language model & fine-tune w/ self-terminating and osl):
# (α = 0.65): " a <unk> of the <unk> " .
# (α = 0.95): " a <unk> of the <unk> " .
# (α = 0.99): " a <unk> of the <unk> " .
#
# (focal):
# (γ = 4): " a <unk> of the <unk> " .
#
#
# Index 983:
# (origin): In 2015 , Fernandez featured in <unk> Singh 's Roy , a romantic thriller ,
# (prefix): In 2015 , Fernandez featured in <unk> Singh 's Roy
# (target):   , a romantic thriller ,
#
# (self-terminating):
# (ε = 1E-2): <unk> , a <unk> of the <unk> <unk> , which was
# (ε = 1E-3): <unk> , a <unk> , and a <unk> .
# (ε = 1E-4): <unk> , a <unk> <unk> , and a <unk> , a <unk> , and a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a young , a man who died in childbirth .
#
# (language model):
# (seed = 0): <unk> , a <unk> <unk> , and a <unk> <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating):
# (ε = 1E-4): <unk> , a <unk> <unk> , a <unk> , and a <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:
# (ε = 1E-4): <unk> , a <unk> , and a <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating and osl):
# (α = 0.65): <unk> , a <unk> <unk> , and a <unk> , and a <unk> , a <unk> , a <unk> , and a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , two <unk> , two <unk> , two vertebrae , two vertebrae , two vertebrae , two vertebrae , two vertebrae , two vertebrae , two vertebrae , two vertebrae , two vertebrae , two vertebrae , two feet , two feet , two feet , two feet , two feet , two feet , two feet , a half feet , and a half feet ( 1 @.@ 9 m ) .
# (α = 0.95): <unk> , a <unk> <unk> , and a <unk> , and a <unk> , a <unk> , a <unk> , a <unk> , and a <unk> , and a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a younger , whom she died in a family .
# (α = 0.99): <unk> , a <unk> <unk> , and a <unk> , and a <unk> , a <unk> , and a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , leather , and two children .
#
# (focal):
# (γ = 4): <unk> , a <unk> of the <unk> <unk> , and the <unk> of the <unk> .
#
#
# Index 984:
# (origin): described as a " boring , exhausting and pretentious " film .
# (prefix): described as a " boring , exhausting and pretentious "
# (target):   film .
#
# (self-terminating):
# (ε = 1E-2): , and that the " <unk> " is a " <unk> " .
# (ε = 1E-3): , and that the " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , "
# (ε = 1E-4): .
#
# (language model):
# (seed = 0): .
#
# (pretrain w/ language model & fine-tune w/ self-terminating):
# (ε = 1E-4): .
#
# (pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:
# (ε = 1E-4): .
#
# (pretrain w/ language model & fine-tune w/ self-terminating and osl):
# (α = 0.65): , and that it " is a little more <unk> " .
# (α = 0.95): , and " <unk> " , and " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " <unk> " , " The <unk> " , " The <unk> " , " The <unk> " , " The Forge " , " The Forge " , " The Forge " , " The Forge " , " The Forge " , " The Forge " , " The Forge " , " The Forge " , " The Forge " , " Man " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas Eat Pudding " , " Christmas Cake " , " Man " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " One Put Ahk " , " One Put Ahk II " , " Man " , " Christmas " , " One " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " The Dream " , " Man " , " The Dream " , " Man " , " The Dream " , " Man " , " The Dream " , " Man " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Man " , " Christmas " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Christmas " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Man " , " Christma ...
# (α = 0.99): , and that it " is a <unk> of the <unk> of the <unk> of the <unk> " .
#
# (focal):
# (γ = 4): , and " <unk> " .
#
#
# Index 985:
# (origin): Fernandez played dual roles , Ayesha <unk> , a filmmaker in a relationship with another filmmaker ( played by Arjun <unk> ) and <unk> <unk> , a girl in love with a thief ( played by <unk> Kapoor ) .
# (prefix): Fernandez played dual roles , Ayesha <unk> , a filmmaker
# (target):   in a relationship with another filmmaker ( played by Arjun <unk> ) and <unk> <unk> , a girl in love with a thief ( played by <unk> Kapoor ) .
#
# (self-terminating):
# (ε = 1E-2): , and a <unk> , and a <unk> of
# (ε = 1E-3): , and a <unk> , a <unk> , and a <unk> .
# (ε = 1E-4): , and a <unk> , and a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a <unk> , a friend , a student , a student , a daughter , a son , a boy , a son , a son , a son , a son , a son , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daughter , a daug ...
#
# (language model):
# (seed = 0): , and a <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating):
# (ε = 1E-4): , and a <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:
# (ε = 1E-4): , and a <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating and osl):
# (α = 0.65): , and a <unk> , and a <unk> , a <unk> , and a <unk> .
# (α = 0.95): , and a <unk> , and a <unk> , a <unk> , and a <unk> .
# (α = 0.99): , and a <unk> , and a <unk> , a <unk> , and a <unk> , and a <unk> , a <unk> , and a <unk> .
#
# (focal):
# (γ = 4): , and a <unk> .
#
#
# Index 996:
# (origin): According to <unk> , and the horror thriller Definition of Fear , which marks her Hollywood debut .
# (prefix): According to <unk> , and the horror thriller Definition of
# (target):   Fear , which marks her Hollywood debut .
#
# (self-terminating):
# (ε = 1E-2): the <unk> , the song is a " <unk> " , and
# (ε = 1E-3): the <unk> , the song was " <unk> " .
# (ε = 1E-4): the <unk> , the song was released in the United States on November 30 , 2003 .
#
# (language model):
# (seed = 0): the <unk> , the <unk> of the <unk>
#
# (pretrain w/ language model & fine-tune w/ self-terminating):
# (ε = 1E-4): the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , the <unk> , and the <unk> of the <unk> , and the <unk> of the <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating) w/ untied word embedding:
# (ε = 1E-4): the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , the <unk> , and the <unk> of the <unk> .
#
# (pretrain w/ language model & fine-tune w/ self-terminating and osl):
# (α = 0.65): the <unk> , the <unk> of the <unk> , the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
# (α = 0.95): the <unk> , the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> , the <unk> of the <unk> , and the <unk> of the <unk> .
# (α = 0.99): the <unk> , the song was " <unk> " and " <unk> " .
#
# (focal):
# (γ = 4): the <unk> , the <unk> of the <unk> , is a <unk> , and the <unk> of the <unk> .

# %%
lm_cont
# Out:
# {'0': ['she', 'is', 'a', '<unk>', 'of', 'the', 'family', '.']}
